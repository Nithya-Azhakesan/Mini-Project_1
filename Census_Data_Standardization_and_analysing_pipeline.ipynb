# %% [markdown]
# <a href="https://colab.research.google.com/github/Nithya-Azhakesan/Mini-Project_1/blob/main/Census_Data_Standardization_and_analysing_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/census_2011.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: float64(115), int64(1), object(2)
# memory usage: 590.1+ KB

# %%
df.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     640.000000  6.100000e+02  6.100000e+02  6.070000e+02  6.040000e+02
# mean      320.500000  1.852620e+06  9.685726e+05  9.139882e+05  1.190550e+06
# std       184.896367  1.435578e+06  7.926455e+05  7.479293e+05  1.050630e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.148625e+05  4.180382e+05  3.986990e+05  4.796545e+05
# 50%       320.500000  1.557367e+06  7.939620e+05  7.556020e+05  9.793575e+05
# 75%       480.250000  2.565248e+06  1.318615e+06  1.253832e+06  1.602260e+06
# max       640.000000  1.000978e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#         Literate_Male  Literate_Female            SC       Male_SC  \
# count    6.090000e+02     6.130000e+02  6.050000e+02  6.170000e+02
# mean     6.739088e+05     5.129481e+05  3.177854e+05  1.624509e+05
# std      5.683384e+05     4.801441e+05  3.172010e+05  1.625607e+05
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 118 columns):
#  #    Column                                                                                                   Dtype
# ---   ------                                                                                                   -----
#  0    District code                                                                                            int64
#  1    State name                                                                                               object
#  2    District name                                                                                            object
#  3    Population                                                                                               float64
#  4    Male                                                                                                     float64
# ...

# %% [markdown]
# #Task 1: Rename the Column names

# %%
#Task 1: Rename the Column names
df=df.rename(columns={'State name':'State/UT','District name':'District','Male_Literate':' Literate_Male','Female_Literate':'Literate_Female',
                   'Rural_Households':'Households_Rural','Urban_ Households':'Households_Urban','Age_Group_0_29':'Young_and_Adult',
                   'Age_Group_30_49':'Middle_Aged','Age_Group_50':'Senior_Citizen','Age not stated':'Age_Not_Stated'
                   })
df
# Out:
#      District code                     State/UT                   District  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population      Male    Female  Literate   Literate_Male  \
# ...

# %% [markdown]
# #Task 2: Rename State/UT Names

# %%
df1=df['State/UT'].str.title()
df2=df1.str.replace(' And',' and')
df2
# Out:
# 0                Jammu and Kashmir
# 1                Jammu and Kashmir
# 2                Jammu and Kashmir
# 3                Jammu and Kashmir
# 4                Jammu and Kashmir
#                   ...
# 635                    Pondicherry
# 636                    Pondicherry
# 637    Andaman and Nicobar Islands
# 638    Andaman and Nicobar Islands
# 639    Andaman and Nicobar Islands
# Name: State/UT, Length: 640, dtype: object

# %% [markdown]
# #Task 3: New State/UT formation

# %%
#Task 3: New State/UT formation
tf=pd.read_table('/content/Telangana.txt')

# %%
mylist=['Adilabad','Nizamabad','Karimnagar','Medak','Hyderabad','Rangareddy','Mahbubnagar',
'Nalgonda','Warangal','Khammam']

# %%
df.loc[df['District'].isin(mylist),'State/UT']='Telangana'

# %%
df
# Out:
#      District code                     State/UT                   District  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population      Male    Female  Literate   Literate_Male  \
# ...

# %%
df[df['State/UT']=='Telangana']
# Out:
#      District code   State/UT     District  Population       Male     Female  \
# 531            532  Telangana     Adilabad   2741239.0        NaN  1371642.0
# 532            533  Telangana    Nizamabad   2551335.0  1250641.0  1300694.0
# 533            534  Telangana   Karimnagar   3776269.0  1880800.0  1895469.0
# 534            535  Telangana        Medak   3033288.0  1523030.0  1510258.0
# 535            536  Telangana    Hyderabad   3943323.0  2018575.0  1924748.0
# 536            537  Telangana   Rangareddy   5296741.0  2701008.0  2595733.0
# 537            538  Telangana  Mahbubnagar   4053028.0  2050386.0  2002642.0
# 538            539  Telangana     Nalgonda   3488809.0  1759772.0  1729037.0
# 539            540  Telangana     Warangal   3512576.0  1759281.0  1753295.0
# 540            541  Telangana      Khammam   2797370.0  1390988.0  1406382.0
#
#       Literate   Literate_Male  Literate_Female        SC  ...  \
# ...

# %%
mylist2=['Leh','Kargil']

# %%
df.loc[df['District'].isin(mylist2),'State/UT']='Ladakh'

# %%
df[df['State/UT']=='Ladakh']
# Out:
#    District code State/UT District  Population  Male   Female  Literate  \
# 3              4   Ladakh   Kargil    140802.0   NaN  63017.0       NaN
#
#     Literate_Male  Literate_Female    SC  ...  Power_Parity_Rs_90000_150000  \
# 3         56301.0          29935.0  18.0  ...                          27.0
#
#    Power_Parity_Rs_45000_150000  Power_Parity_Rs_150000_240000  \
# 3                         114.0                           12.0
#
#    Power_Parity_Rs_240000_330000  Power_Parity_Rs_150000_330000  \
# 3                           18.0                           30.0
#
#    Power_Parity_Rs_330000_425000  Power_Parity_Rs_425000_545000  \
# 3                           19.0                            3.0
#
#    Power_Parity_Rs_330000_545000  Power_Parity_Above_Rs_545000  \
# 3                           22.0                           7.0
#
#    Total_Power_Parity
# 3               214.0
#
# [1 rows x 118 columns]

# %% [markdown]
# #Task 4: Find and process Missing Data

# %%
df.shape
# Out:
# (640, 118)

# %%
pd.options.display.max_columns=118

# %%
df.head()
# Out:
#    District code           State/UT     District  Population      Male  \
# 0              1  JAMMU AND KASHMIR      Kupwara    870354.0  474190.0
# 1              2  JAMMU AND KASHMIR       Badgam    753745.0       NaN
# 2              3  JAMMU AND KASHMIR  Leh(Ladakh)    133487.0   78971.0
# 3              4             Ladakh       Kargil    140802.0       NaN
# 4              5  JAMMU AND KASHMIR        Punch         NaN  251899.0
#
#      Female  Literate   Literate_Male  Literate_Female      SC  Male_SC  \
# 0  396164.0  439654.0        282823.0         156831.0  1048.0   1046.0
# 1  355704.0  335649.0        207741.0         127908.0     NaN    343.0
# 2   54516.0   93770.0         62834.0          30936.0   488.0    444.0
# 3   63017.0       NaN         56301.0          29935.0    18.0     12.0
# 4  224936.0  261724.0        163333.0          98391.0   556.0    406.0
#
#    Female_SC        ST  Male_ST  Female_ST   Workers  Male_Workers  \
# ...

# %%
df_missing=df.isna()
df_missing
# Out:
#      District code  State/UT  District  Population   Male  Female  Literate  \
# 0            False     False     False       False  False   False     False
# 1            False     False     False       False   True   False     False
# 2            False     False     False       False  False   False     False
# 3            False     False     False       False   True   False      True
# 4            False     False     False        True  False   False     False
# ..             ...       ...       ...         ...    ...     ...       ...
# 635          False     False     False       False  False   False     False
# 636          False     False     False       False  False   False     False
# 637          False     False     False       False  False    True     False
# 638          False     False     False       False  False   False     False
# 639          False     False     False        True  False   False     False
#
# ...

# %%
df_missing.head()
# Out:
#    District code  State/UT  District  Population   Male  Female  Literate  \
# 0          False     False     False       False  False   False     False
# 1          False     False     False       False   True   False     False
# 2          False     False     False       False  False   False     False
# 3          False     False     False       False   True   False      True
# 4          False     False     False        True  False   False     False
#
#     Literate_Male  Literate_Female     SC  Male_SC  Female_SC     ST  Male_ST  \
# 0           False            False  False    False      False  False    False
# 1           False            False   True    False      False  False    False
# 2           False            False  False    False      False  False    False
# 3           False            False  False    False      False  False    False
# 4           False            False  False    False       True  False    False
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 3622

# %%
df1=df.fillna(0)

# %%
df1
# Out:
#      District code                     State/UT                   District  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4                       Ladakh                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population      Male    Female  Literate   Literate_Male  \
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df1
# Out:
#      District code                     State/UT                   District  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4                       Ladakh                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population      Male    Female  Literate   Literate_Male  \
# ...

# %%
df1['Population']=df1['Male']+df1['Female']

# %%
new_df1=df1.fillna({'Population':('Male'+'Female'),'Households':('Households_Rural'+'Urban_Households'),'Literate':('Literate_Male'+'Literate_Female')})

# %%
new_df1
# Out:
#      District code                     State/UT                   District  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4                       Ladakh                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population      Male    Female  Literate   Literate_Male  \
# ...

# %% [markdown]
#  Task 5: Save Data to MongoDB

# %%
new_df1=df1.fillna({})
new_df1
# Out:
#      District code                     State/UT                   District  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4                       Ladakh                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population      Male    Female  Literate   Literate_Male  \
# ...
